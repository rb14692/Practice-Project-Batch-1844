# %%
# Avacado Project

# %%
# Problem Statement:
# Avocado is a fruit consumed by people heavily in the United States. 

#Content
#This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV. 
#The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados. 
#Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags. 
#The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.

#Some relevant columns in the dataset:

#Date - The date of the observation
#AveragePrice - the average price of a single avocado
#type - conventional or organic
#year - the year
#Region - the city or region of the observation
#Total Volume - Total number of avocados sold
#4046 - Total number of avocados with PLU 4046 sold
#4225 - Total number of avocados with PLU 4225 sold
#4770 - Total number of avocados with PLU 4770 sold

#Inspiration /Label 

#The dataset can be seen in two angles to find the region and find the average price .
#The goal is to predict the average price which is continuous in nature of the different type of avocado and using the region that in which region they are lying.

# %%
# First of all import all the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib as jb
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LogisticRegression,Lasso,LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.decomposition import PCA
from scipy.stats import zscore
from sklearn.model_selection import cross_val_score

# %%
#Importing Dataset and Data Information

# %%
df=pd.read_csv('C:\\Users\\lenovo\\Downloads\\avocado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
#as we drop index column beacuse it just kind of id which have no effect on dataset
df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
#checking the total rows and total columns
df.shape
# Out:
# (18249, 13)

# %%
# we have 18249 rows and 13 columns

# %%
# Understanding Dataset

# %%
# Features:

#Date - The date of the observation
#type - conventional or organic
#year - the year
#Total Volume - Total number of avocados sold
#4046 - Total number of avocados with PLU 4046 sold
#4225 - Total number of avocados with PLU 4225 sold
#4770 - Total number of avocados with PLU 4770 sold
#Small Bags- Small size bags
#Large Bags- Large size bags
#XL Bags- Extra Large size bags
#Total Bags- Total no of Bags


#Target Variable:

#AveragePrice - the average price of a single avocado
#Region - the city or region of the observation

# %%
# Reviewing Data Set at initial stage, found Target variable data is 'Average Price' and 'Region'.

# %%
# checking the columns index present in dataset
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
#Information about the data columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
# here we can see 3 columns i.e Date, type and region are object data columns and rest other 10 columns are float datatype

# %%
# no. of rows and coloumns
df.shape
# Out:
# (18249, 13)

# %%
# here we have 18249 rows and 13 columns in dataset

# %%
#Extract the Month from DOB into separate column
df['Month'] = pd.DatetimeIndex(df['Date']).month
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month
# 0  Albany     12
# 1  Albany     12
# 2  Albany     12
# 3  Albany     12
# 4  Albany     11

# %%
#Extract the Date from DOB into separate column
df['Date'] = pd.DatetimeIndex(df['Date']).day
df.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0    27          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1    20          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2    13          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3     6          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4    29          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11

# %%
#checking the value counts of each date
df.Date.value_counts()
# Out:
# 4     756
# 11    756
# 18    755
# 25    755
# 1     648
# 26    648
# 5     648
# 12    648
# 3     648
# 8     648
# 15    648
# 22    648
# 24    648
# 17    648
# 10    648
# 19    648
# 7     540
# 14    540
# 21    540
# 28    540
# 27    540
# 20    540
# 29    540
# 13    540
# 6     539
# 2     432
# 9     432
# 23    432
# 30    432
# 31    432
# 16    432
# Name: Date, dtype: int64

# %%
#checking the value counts of each type
df.type.value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
#co relation of total volume to total bag
df[['Total Volume','Total Bags']].corr()
# Out:
#               Total Volume  Total Bags
# Total Volume      1.000000    0.963047
# Total Bags        0.963047    1.000000

# %%
#checking the average year of volume of avacado per year
df.groupby('year')['Total Volume'].mean()
# Out:
# year
# 2015    7.810274e+05
# 2016    8.584206e+05
# 2017    8.623393e+05
# 2018    1.066928e+06
# Name: Total Volume, dtype: float64

# %%
#checking the organic type of avacado 
organic = df[df['type'] == 'organic']
organic
# Out:
#        Date  AveragePrice  Total Volume     4046     4225    4770  Total Bags  \
# 9126     27          1.83        989.55     8.16    88.59    0.00      892.80
# 9127     20          1.89       1163.03    30.24   172.14    0.00      960.65
# 9128     13          1.85        995.96    10.44   178.70    0.00      806.82
# 9129      6          1.84       1158.42    90.29   104.18    0.00      963.95
# 9130     29          1.94        831.69     0.00    94.73    0.00      736.96
# ...     ...           ...           ...      ...      ...     ...         ...
# 18244     4          1.63      17074.83  2046.96  1529.20    0.00    13498.67
# 18245    28          1.71      13888.04  1191.70  3431.50    0.00     9264.84
# 18246    21          1.87      13766.76  1191.92  2452.79  727.94     9394.11
# 18247    14          1.93      16205.22  1527.63  2981.04  727.01    10969.54
# 18248     7          1.62      17489.58  2894.77  2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags     type  year            region  \
# 9126       892.80        0.00          0.0  organic  2015            Albany
# 9127       960.65        0.00          0.0  organic  2015            Albany
# 9128       806.82        0.00          0.0  organic  2015            Albany
# 9129       948.52       15.43          0.0  organic  2015            Albany
# 9130       736.96        0.00          0.0  organic  2015            Albany
# ...           ...         ...          ...      ...   ...               ...
# 18244    13066.82      431.85          0.0  organic  2018  WestTexNewMexico
# 18245     8940.04      324.80          0.0  organic  2018  WestTexNewMexico
# 18246     9351.80       42.31          0.0  organic  2018  WestTexNewMexico
# 18247    10919.54       50.00          0.0  organic  2018  WestTexNewMexico
# 18248    11988.14       26.01          0.0  organic  2018  WestTexNewMexico
#
#        Month
# 9126      12
# 9127      12
# 9128      12
# 9129      12
# 9130      11
# ...      ...
# 18244      2
# 18245      1
# 18246      1
# 18247      1
# 18248      1
#
# [9123 rows x 14 columns]

# %%
#checking the mean of price at each year of organic type of avacado
organic.groupby('year')['AveragePrice'].mean()
# Out:
# year
# 2015    1.673324
# 2016    1.571684
# 2017    1.735521
# 2018    1.567176
# Name: AveragePrice, dtype: float64

# %%
#finding how much type of avacado is sold in last 4 year
df.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %%
#total no of sale in each year of  4 years
df.groupby('year')['Total Volume'].count()
# Out:
# year
# 2015    5615
# 2016    5616
# 2017    5722
# 2018    1296
# Name: Total Volume, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  int64
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
#  13  Month         18249 non-null  int64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %%
#checking null values using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# checking for null values in dataframe
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# Month           0
# dtype: int64

# %%
# There are no null or missing values in data set

# %%
# check the statestics of dataset
df.describe()
# Out:
#                Date  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      15.662612      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std        8.776281      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        1.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%        8.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       16.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       23.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       31.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year         Month
# count  18249.000000  18249.000000
# mean    2016.147899      6.177215
# std        0.939938      3.534130
# min     2015.000000      1.000000
# 25%     2015.000000      3.000000
# 50%     2016.000000      6.000000
# 75%     2017.000000      9.000000
# max     2018.000000     12.000000

# %%
# here we can see the count,mean,std deviation,min,max,1st,2nd and 3rd quartile value of each column.
# Above statatics data show that there multiple outliers mostly in XLargeBags.
# There is also difference between mean and 50% value in some of the columns which used to get fix for better prediction

# %%
# Data Visualization

# %%
#checking ratio of year and price that which year had max average price
sns.barplot(x = "year" , y = "AveragePrice" ,data=df )
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
#from the above graph we can see that 2017 year is that year where max average price is there

# %%
#checking ratio of month and price that which year had max average price
sns.barplot(x = "Month" , y = "AveragePrice" ,data=df )
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %%
# from the above graph we can see that sept and october is the month where max no of average price is there

# %%
sns.lineplot(x = 'year', y = 'AveragePrice', data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
#checking ratio of type and price that which year had max average price
sns.barplot(x = "type" , y = "AveragePrice" ,data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %%
# from the above graph we can see that organic type of avacado is having the more price per unit then conventional

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="Month", y="AveragePrice", hue='type', data=df)
plt.show()

# %%
# from the above lineplot graph we can see that here is hike between month 8-10 of both type of avacado

# %%
plt.figure(figsize=(24,15))
sns.barplot(x='region',y='AveragePrice',data=df)
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('relation of Price and Region')
# Out:
# Text(0.5, 1.0, 'relation of Price and Region')

# %%
# from the above graph we can see that HartfordSpringfield ,SanFrancisco and NewYork are having more average price as compared to other region

# %%
date=df.groupby('Date').mean()
plt.figure(figsize=(12,10))
date['AveragePrice'].plot()
plt.title('Average_Price')
# Out:
# Text(0.5, 1.0, 'Average_Price')

# %%
# from the above graph we can see that on date 28,29 and 30 the price of avacado is high

# %%
month=df.groupby('Month').mean()
plt.figure(figsize=(12,10))
month['AveragePrice'].plot()
plt.title('Average_Price')
# Out:
# Text(0.5, 1.0, 'Average_Price')

# %%
# from the above graph we can see that in between august to october month the price of avacado is much higher as comapared to other months

# %%
#plotting histogram for univariate analysis and checking the Normal Distribution
df.hist(figsize=(20,20), grid = True, layout = (4,4), bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>],
#        [<AxesSubplot:title={'center':'4225'}>,
#         <AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>,
#         <AxesSubplot:title={'center':'Small Bags'}>],
#        [<AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'Month'}>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
#Making the categorical data into numercial for better EDA
column = ['type','region']
le = LabelEncoder()
for i in column:
    df[i] = le.fit_transform(df[i].astype(str))

print(df.dtypes)
# Out:
# Date              int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# Month             int64
# dtype: object

# %%
df.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0    27          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1    20          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2    13          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3     6          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4    29          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Month
# 0     8603.62       93.25          0.0     0  2015       0     12
# 1     9408.07       97.49          0.0     0  2015       0     12
# 2     8042.21      103.14          0.0     0  2015       0     12
# 3     5677.40      133.76          0.0     0  2015       0     12
# 4     5986.26      197.69          0.0     0  2015       0     11

# %%
df.type = df.type.astype(float)

# %%
#plotting the boxplot of each column to check the outliers 
df.plot(kind='box',subplots = True,layout=(4,5),figsize = (15,10))
# Out:
# Date                AxesSubplot(0.125,0.71587;0.133621x0.16413)
# AveragePrice     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Total Volume      AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4046             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 4225             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# 4770               AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Total Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Small Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Large Bags      AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# type               AxesSubplot(0.125,0.321957;0.133621x0.16413)
# year            AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# region           AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# Month           AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# dtype: object

# %%
# we can see the outliers are present in most of the data.

# %%
#calculate the zscore
z = np.abs(zscore(df))
print(z)
# Out:
#            Date  AveragePrice  Total Volume      4046      4225      4770  \
# 0      1.291857      0.188689      0.227716  0.230816  0.199902  0.212091
# 1      0.494231      0.139020      0.230427  0.231103  0.208054  0.211997
# 2      0.303396      1.182069      0.212085  0.231007  0.154478  0.211325
# 3      1.101022      0.809551      0.223444  0.230741  0.185350  0.211864
# 4      1.519750      0.312861      0.231538  0.230891  0.208719  0.211834
# ...         ...           ...           ...       ...       ...       ...
# 18244  1.328915      0.556347      0.241373  0.230017  0.243857  0.212540
# 18245  1.405803      0.755023      0.242296  0.230693  0.242277  0.212540
# 18246  0.608177      1.152375      0.242331  0.230693  0.243090  0.205766
# 18247  0.189449      1.301382      0.241625  0.230428  0.242651  0.205774
# 18248  0.987075      0.531512      0.241253  0.229347  0.243170  0.210450
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags      type      year  \
# 0        0.234170    0.232647    0.222352      0.17558  0.999836  1.221282
# 1        0.233350    0.231568    0.222335      0.17558  0.999836  1.221282
# 2        0.234730    0.233399    0.222311      0.17558  0.999836  1.221282
# 3        0.237096    0.236568    0.222186      0.17558  0.999836  1.221282
# 4        0.236718    0.236154    0.221924      0.17558  0.999836  1.221282
# ...           ...         ...         ...          ...       ...       ...
# 18244    0.229301    0.226665    0.220964      0.17558  1.000164  1.970504
# 18245    0.233594    0.232196    0.221403      0.17558  1.000164  1.970504
# 18246    0.233463    0.231644    0.222561      0.17558  1.000164  1.970504
# 18247    0.231866    0.229543    0.222529      0.17558  1.000164  1.970504
# 18248    0.230807    0.228111    0.222628      0.17558  1.000164  1.970504
#
#          region     Month
# 0      1.700252  1.647632
# 1      1.700252  1.647632
# 2      1.700252  1.647632
# 3      1.700252  1.647632
# 4      1.700252  1.364669
# ...         ...       ...
# 18244  1.700811  1.181997
# 18245  1.700811  1.464959
# 18246  1.700811  1.464959
# 18247  1.700811  1.464959
# 18248  1.700811  1.464959
#
# [18249 rows x 14 columns]

# %%
#checking the co-relation of all column to each other
df_cor = df.corr()
plt.figure(figsize=(30,25))
sns.heatmap(df_cor,annot=True)
plt.plot()
# Out:
# []

# %%
# we can see that year is most negative co related column among all columns and also the difference is very close of each column

# %%
threshold = 3
print(np.where(z<3))
print(df.shape)
# Out:
# (array([    0,     0,     0, ..., 18248, 18248, 18248], dtype=int64), array([ 0,  1,  2, ..., 11, 12, 13], dtype=int64))
# (18249, 14)

# %%
#Assign the value to df_new which are less the threshold value and removing the outliers
df_new = df[(z<3).all(axis = 1)]

# %%
print(df.shape)
print(df_new.shape)
df = df_new
print('Shape after removing outlires',df.shape)
# Out:
# (17651, 14)
# (17651, 14)
# Shape after removing outlires (17651, 14)

# %%
#now finding the mean value of each column 
print(df['4225'].mean())
print(df['Total Bags'].mean())
print(df['Small Bags'].mean())
# Out:
# 166445.31769647403
# 129933.68940410927
# 101614.60839952317

# %%
#replace the outlier value to its mean value to remove outliers
df.loc[df['4225']<3,'4225'] = np.mean(df['4225'])
df.loc[df['Total Bags']<4.8,'Total Bags'] = np.mean(df['Total Bags'])
df.loc[df['Small Bags']<4,'Small Bags'] = np.mean(df['Small Bags'])

# %%
df.skew()
# Out:
# Date            0.011778
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455664
# 4770            5.117170
# Total Bags      4.066780
# Small Bags      4.222709
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# Month           0.107408
# dtype: float64

# %%
#making the skew less than or equal to 0.55 for better prediction and plotting Normal distribution
skew=('Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags')
for col in skew :
    if df.skew().loc[col]>0.55:
        df[col] = np.log1p(df[col])

# %%
df.skew()
# Out:
# Date            0.011778
# AveragePrice    0.377432
# Total Volume   -0.049950
# 4046           -0.420273
# 4225           -0.503957
# 4770            0.068532
# Total Bags     -0.319074
# Small Bags     -0.435520
# Large Bags     -0.610874
# XLarge Bags     1.216238
# type           -0.037741
# year            0.229976
# region          0.012798
# Month           0.107408
# dtype: float64

# %%
#plotting histogram for univariate analysis and checking the Normal Distribution
df.hist(figsize=(20,20), grid = True, layout = (4,4), bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>],
#        [<AxesSubplot:title={'center':'4225'}>,
#         <AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>,
#         <AxesSubplot:title={'center':'Small Bags'}>],
#        [<AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>,
#         <AxesSubplot:title={'center':'type'}>,
#         <AxesSubplot:title={'center':'year'}>],
#        [<AxesSubplot:title={'center':'region'}>,
#         <AxesSubplot:title={'center':'Month'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
# we can see that average price, total bags and total volume is well normally distributed data among all column

# %%
#assign the value of x and y for training and testing phase
x = df.drop(columns=['AveragePrice','Date'])
y = df[["AveragePrice"]]
print(x.shape)
print(y.shape)
# Out:
# (17651, 12)
# (17651, 1)

# %%
# here we are using Average Price as output variable and useing to do the prediction

# %%
#Standardize the value of x so that mean will 0 and SD will become 1 , and make the data as normal distributed
sc = StandardScaler()
sc.fit_transform(x)
x = pd.DataFrame(x,columns=x.columns)

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),LinearRegression(),GradientBoostingRegressor()]
max_r2_score = 0
for r_state in range(40,90):
    train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = r_state,test_size = 0.33)
    for i in model:
        i.fit(train_x,train_y)
        pre = i.predict(test_x)
        r2_sc = r2_score(test_y,pre)
        print("R2 score correspond to random state " ,r_state ,"is", r2_sc)
        if r2_sc> max_r2_score:
            max_r2_score=r2_sc
            final_state = r_state
            final_model = i
            
print()
print()
print()
print()
print("max R2 score correspond to random state " ,final_state , "is" , max_r2_score ,"and model is",final_model)
# Out:
# R2 score correspond to random state  40 is 0.7536699106049486
# R2 score correspond to random state  40 is 0.8374592350327745
# R2 score correspond to random state  40 is 0.5703923878330162
# R2 score correspond to random state  40 is 0.544926432627854
# R2 score correspond to random state  40 is 0.7503467423884156
# R2 score correspond to random state  41 is 0.733877566294807
# R2 score correspond to random state  41 is 0.8281730760420748
# R2 score correspond to random state  41 is 0.538577895014404
# R2 score correspond to random state  41 is 0.5362877321971128
# R2 score correspond to random state  41 is 0.7462086035627709
# R2 score correspond to random state  42 is 0.7154109485674857
# R2 score correspond to random state  42 is 0.8272814301920477
# R2 score correspond to random state  42 is 0.5596577508018745
# R2 score correspond to random state  42 is 0.5428506636427334
# R2 score correspond to random state  42 is 0.7404599605481431
# R2 score correspond to random state  43 is 0.7133544849645626
# R2 score correspond to random state  43 is 0.8254308998757397
# R2 score correspond to random state  43 is 0.5582227870718004
# R2 score correspond to random state  43 is 0.5426734613070496
# R2 score correspond to random state  43 is 0.7462789717647456
# R2 score correspond to random state  44 is 0.7337078167865043
# R2 score correspond to random state  44 is 0.8282751057998612
# R2 score correspond to random state  44 is 0.565007375554372
# R2 score correspond to random state  44 is 0.5275402020432216
# R2 score correspond to random state  44 is 0.7364471087846254
# R2 score correspond to random state  45 is 0.7454233754252381
# R2 score correspond to random state  45 is 0.8287714206742463
# R2 score correspond to random state  45 is 0.5665369742762105
# R2 score correspond to random state  45 is 0.552018860759718
# R2 score correspond to random state  45 is 0.7415355977630591
# R2 score correspond to random state  46 is 0.7243774306130799
# R2 score correspond to random state  46 is 0.8315240017150916
# R2 score correspond to random state  46 is 0.557433410853579
# R2 score correspond to random state  46 is 0.5527736932611755
# R2 score correspond to random state  46 is 0.749501831376062
# R2 score correspond to random state  47 is 0.7346357576631575
# R2 score correspond to random state  47 is 0.827736705602328
# R2 score correspond to random state  47 is 0.5722914649712815
# R2 score correspond to random state  47 is 0.54034605327499
# R2 score correspond to random state  47 is 0.7447170495627602
# R2 score correspond to random state  48 is 0.762570342102201
# R2 score correspond to random state  48 is 0.8262618225288333
# R2 score correspond to random state  48 is 0.566175875023295
# R2 score correspond to random state  48 is 0.5459307397846485
# R2 score correspond to random state  48 is 0.7420468581118115
# R2 score correspond to random state  49 is 0.7259127958105187
# R2 score correspond to random state  49 is 0.8255371151040708
# R2 score correspond to random state  49 is 0.5537962431804965
# R2 score correspond to random state  49 is 0.5405653299974156
# R2 score correspond to random state  49 is 0.743276958722356
# R2 score correspond to random state  50 is 0.7459259715005917
# R2 score correspond to random state  50 is 0.8331783005731987
# R2 score correspond to random state  50 is 0.5530321363487402
# R2 score correspond to random state  50 is 0.5441328947013236
# R2 score correspond to random state  50 is 0.7404980465085816
# R2 score correspond to random state  51 is 0.7435871288734863
# R2 score correspond to random state  51 is 0.831121559155518
# R2 score correspond to random state  51 is 0.553780791896584
# R2 score correspond to random state  51 is 0.5425736926744618
# R2 score correspond to random state  51 is 0.7381344181829376
# R2 score correspond to random state  52 is 0.7171743435363648
# R2 score correspond to random state  52 is 0.822661785877112
# R2 score correspond to random state  52 is 0.5697189421851958
# R2 score correspond to random state  52 is 0.5455671667097768
# R2 score correspond to random state  52 is 0.7456063559408379
# R2 score correspond to random state  53 is 0.7502999062692948
# R2 score correspond to random state  53 is 0.8356558890699237
# R2 score correspond to random state  53 is 0.5429540224434019
# R2 score correspond to random state  53 is 0.550663808196451
# R2 score correspond to random state  53 is 0.7425230057075556
# R2 score correspond to random state  54 is 0.728370349912545
# R2 score correspond to random state  54 is 0.8373834191353019
# R2 score correspond to random state  54 is 0.5567151797085906
# R2 score correspond to random state  54 is 0.5364198520335213
# R2 score correspond to random state  54 is 0.7366008283155207
# R2 score correspond to random state  55 is 0.7186979373629555
# R2 score correspond to random state  55 is 0.8236392318998603
# R2 score correspond to random state  55 is 0.5649651218911416
# R2 score correspond to random state  55 is 0.5319210408803545
# R2 score correspond to random state  55 is 0.7394610455582076
# R2 score correspond to random state  56 is 0.7402218915823136
# R2 score correspond to random state  56 is 0.8211365778573971
# R2 score correspond to random state  56 is 0.564934082623525
# R2 score correspond to random state  56 is 0.5487437706421927
# R2 score correspond to random state  56 is 0.7454985790568494
# R2 score correspond to random state  57 is 0.7223077952151029
# R2 score correspond to random state  57 is 0.8282536746694267
# R2 score correspond to random state  57 is 0.5535413423006288
# R2 score correspond to random state  57 is 0.544878533724612
# R2 score correspond to random state  57 is 0.7440428698096813
# R2 score correspond to random state  58 is 0.7392586356342057
# R2 score correspond to random state  58 is 0.837800492602347
# R2 score correspond to random state  58 is 0.5507144933440886
# R2 score correspond to random state  58 is 0.5396438781744757
# R2 score correspond to random state  58 is 0.73995050113008
# R2 score correspond to random state  59 is 0.7208271975882985
# R2 score correspond to random state  59 is 0.8286333668491137
# R2 score correspond to random state  59 is 0.5424888712117407
# R2 score correspond to random state  59 is 0.5347257301559045
# R2 score correspond to random state  59 is 0.736611950876825
# R2 score correspond to random state  60 is 0.7420738310555534
# R2 score correspond to random state  60 is 0.8364045526135928
# R2 score correspond to random state  60 is 0.5705056650227518
# R2 score correspond to random state  60 is 0.5515784282658293
# R2 score correspond to random state  60 is 0.7455751147709284
# R2 score correspond to random state  61 is 0.7309515675441498
# R2 score correspond to random state  61 is 0.8307471928369866
# R2 score correspond to random state  61 is 0.5616281169480913
# R2 score correspond to random state  61 is 0.5380968795656036
# R2 score correspond to random state  61 is 0.7379227207841975
# R2 score correspond to random state  62 is 0.7339634519936638
# R2 score correspond to random state  62 is 0.8243446530267169
# R2 score correspond to random state  62 is 0.5704715542468666
# R2 score correspond to random state  62 is 0.5350595751395397
# R2 score correspond to random state  62 is 0.7388623325774367
# R2 score correspond to random state  63 is 0.7433835841108662
# R2 score correspond to random state  63 is 0.8366588134220052
# R2 score correspond to random state  63 is 0.5619300913961461
# R2 score correspond to random state  63 is 0.5516086346586683
# R2 score correspond to random state  63 is 0.7490698061634051
# R2 score correspond to random state  64 is 0.727705866825049
# R2 score correspond to random state  64 is 0.8325309005331549
# R2 score correspond to random state  64 is 0.5598860106568568
# R2 score correspond to random state  64 is 0.5457698106297889
# R2 score correspond to random state  64 is 0.7429409571677534
# R2 score correspond to random state  65 is 0.7486135506898055
# R2 score correspond to random state  65 is 0.8300652444678993
# R2 score correspond to random state  65 is 0.5548685156395603
# R2 score correspond to random state  65 is 0.543622361135172
# R2 score correspond to random state  65 is 0.7441759026393215
# R2 score correspond to random state  66 is 0.744764523903124
# R2 score correspond to random state  66 is 0.8324690927179246
# R2 score correspond to random state  66 is 0.5383049828584441
# R2 score correspond to random state  66 is 0.5296878225910437
# R2 score correspond to random state  66 is 0.7401524376476075
# R2 score correspond to random state  67 is 0.7403225324734792
# R2 score correspond to random state  67 is 0.8245760924899006
# R2 score correspond to random state  67 is 0.5575039299571836
# R2 score correspond to random state  67 is 0.5467764048273742
# R2 score correspond to random state  67 is 0.7379580638780412
# R2 score correspond to random state  68 is 0.719502221757397
# R2 score correspond to random state  68 is 0.8288543911975044
# R2 score correspond to random state  68 is 0.54687114984772
# R2 score correspond to random state  68 is 0.5418675232604916
# R2 score correspond to random state  68 is 0.7438324409182258
# R2 score correspond to random state  69 is 0.729821581032106
# R2 score correspond to random state  69 is 0.8362636786863729
# R2 score correspond to random state  69 is 0.5652292139814302
# R2 score correspond to random state  69 is 0.5515609013985024
# R2 score correspond to random state  69 is 0.7414864100034113
# R2 score correspond to random state  70 is 0.7245390814291353
# R2 score correspond to random state  70 is 0.8259193498589109
# R2 score correspond to random state  70 is 0.5546285297253054
# R2 score correspond to random state  70 is 0.539179132725034
# R2 score correspond to random state  70 is 0.7356850477280104
# R2 score correspond to random state  71 is 0.7401706608515222
# R2 score correspond to random state  71 is 0.8322288213161559
# R2 score correspond to random state  71 is 0.5479980139458702
# R2 score correspond to random state  71 is 0.5400039452303322
# R2 score correspond to random state  71 is 0.7422958020569217
# R2 score correspond to random state  72 is 0.7425768297573054
# R2 score correspond to random state  72 is 0.83007616976478
# R2 score correspond to random state  72 is 0.5555391139726995
# R2 score correspond to random state  72 is 0.5399929538086494
# R2 score correspond to random state  72 is 0.735625654882194
# R2 score correspond to random state  73 is 0.728071153079086
# R2 score correspond to random state  73 is 0.8255533192504672
# R2 score correspond to random state  73 is 0.556216732739453
# R2 score correspond to random state  73 is 0.5339701090272528
# R2 score correspond to random state  73 is 0.7353144106189364
# R2 score correspond to random state  74 is 0.7369171040829273
# R2 score correspond to random state  74 is 0.8317553435207302
# R2 score correspond to random state  74 is 0.5499556089807786
# R2 score correspond to random state  74 is 0.5408886901133632
# R2 score correspond to random state  74 is 0.7412046024653339
# R2 score correspond to random state  75 is 0.7568440323927053
# R2 score correspond to random state  75 is 0.8364627231768833
# R2 score correspond to random state  75 is 0.5618391386474015
# R2 score correspond to random state  75 is 0.549005686502157
# R2 score correspond to random state  75 is 0.7438514524156747
# R2 score correspond to random state  76 is 0.7269756694892803
# R2 score correspond to random state  76 is 0.8270297808162538
# R2 score correspond to random state  76 is 0.5642573185499801
# R2 score correspond to random state  76 is 0.5499547905809199
# R2 score correspond to random state  76 is 0.7512256588452968
# R2 score correspond to random state  77 is 0.7361405899763882
# R2 score correspond to random state  77 is 0.8297811266121835
# R2 score correspond to random state  77 is 0.5626202150159808
# R2 score correspond to random state  77 is 0.5438975920588376
# R2 score correspond to random state  77 is 0.7456647015695079
# R2 score correspond to random state  78 is 0.7226651589336308
# R2 score correspond to random state  78 is 0.8311487308801586
# R2 score correspond to random state  78 is 0.5533590482408037
# R2 score correspond to random state  78 is 0.5400314032503379
# R2 score correspond to random state  78 is 0.7455325702670601
# R2 score correspond to random state  79 is 0.7506236675112404
# R2 score correspond to random state  79 is 0.8328347273853847
# R2 score correspond to random state  79 is 0.5552457857905055
# R2 score correspond to random state  79 is 0.5487928856234032
# R2 score correspond to random state  79 is 0.749495905304794
# R2 score correspond to random state  80 is 0.7398758857440099
# R2 score correspond to random state  80 is 0.8251132033066886
# R2 score correspond to random state  80 is 0.551080096255666
# R2 score correspond to random state  80 is 0.5439939688602624
# R2 score correspond to random state  80 is 0.7444655587445479
# R2 score correspond to random state  81 is 0.7544422899381997
# R2 score correspond to random state  81 is 0.8251996117019649
# R2 score correspond to random state  81 is 0.5434283800886385
# R2 score correspond to random state  81 is 0.5339344704217189
# R2 score correspond to random state  81 is 0.7359685896739221
# R2 score correspond to random state  82 is 0.7383453880243764
# R2 score correspond to random state  82 is 0.8342654972675346
# R2 score correspond to random state  82 is 0.5780779648067698
# R2 score correspond to random state  82 is 0.5539792936479958
# R2 score correspond to random state  82 is 0.7404760358388701
# R2 score correspond to random state  83 is 0.7564632073470848
# R2 score correspond to random state  83 is 0.833774378270632
# R2 score correspond to random state  83 is 0.5678728278698978
# R2 score correspond to random state  83 is 0.5461346326228471
# R2 score correspond to random state  83 is 0.744679744909034
# R2 score correspond to random state  84 is 0.7316468434447245
# R2 score correspond to random state  84 is 0.8295155050754535
# R2 score correspond to random state  84 is 0.5665508945804079
# R2 score correspond to random state  84 is 0.5399773290271983
# R2 score correspond to random state  84 is 0.7443576101258651
# R2 score correspond to random state  85 is 0.7439474210511007
# R2 score correspond to random state  85 is 0.8355182334263149
# R2 score correspond to random state  85 is 0.5634672387491826
# R2 score correspond to random state  85 is 0.545509225870721
# R2 score correspond to random state  85 is 0.7378961802994755
# R2 score correspond to random state  86 is 0.7443569607089919
# R2 score correspond to random state  86 is 0.8265417224250098
# R2 score correspond to random state  86 is 0.5587081843901235
# R2 score correspond to random state  86 is 0.5397618469724275
# R2 score correspond to random state  86 is 0.7357400343531233
# R2 score correspond to random state  87 is 0.7451463856917471
# R2 score correspond to random state  87 is 0.8293433914538293
# R2 score correspond to random state  87 is 0.5512640405295592
# R2 score correspond to random state  87 is 0.5382522612529947
# R2 score correspond to random state  87 is 0.7375462217124397
# R2 score correspond to random state  88 is 0.7638563032115382
# R2 score correspond to random state  88 is 0.841564614027358
# R2 score correspond to random state  88 is 0.5594072594862016
# R2 score correspond to random state  88 is 0.5439478810138677
# R2 score correspond to random state  88 is 0.7426843452337775
# R2 score correspond to random state  89 is 0.7360184398686275
# R2 score correspond to random state  89 is 0.8327620536074403
# R2 score correspond to random state  89 is 0.5494354669894934
# R2 score correspond to random state  89 is 0.5526041014605165
# R2 score correspond to random state  89 is 0.7490239788939306
#
#
#
#
# max R2 score correspond to random state  88 is 0.841564614027358 and model is KNeighborsRegressor()

# %%
# max R2 score correspond to random state 88 is 0.841564614027358 and model is KNeighborsRegressor

# %%
#Checking the best parameter for prediction of KNeighborsRegressor Algo using GridSearchCV
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = 88,test_size = 0.33)
KN = KNeighborsRegressor()
parameters={'n_neighbors' : range(1,30)}
gridsearch=GridSearchCV(KN,parameters)
gridsearch.fit(train_x,train_y)
gridsearch.best_params_
# Out:
# {'n_neighbors': 2}

# %%
KNN = KNeighborsRegressor(n_neighbors=2)
KNN.fit(train_x,train_y)
pred = KNN.predict(test_x)
r2_sc = r2_score(test_y,pred)
print("R2 Score :",r2_sc*100)
# Out:
# R2 Score : 85.77018100881875

# %%
print('Mean Absolute Error: ', mean_absolute_error(test_y,pred))
print('Mean squared Error: ', mean_squared_error(test_y,pred))
print('Root Mean Absolute Error: ', np.sqrt(mean_absolute_error(test_y,pred)))
# Out:
# Mean Absolute Error:  0.10102918454935622
# Mean squared Error:  0.02156965236051502
# Root Mean Absolute Error:  0.31785088414122153

# %%
#checking the diff between actual and predicted value using graph
plt.scatter(x=test_y,y=pred)
plt.xlabel('Y_Test')
plt.ylabel('Predicted_Y')
# Out:
# Text(0, 0.5, 'Predicted_Y')

# %%
# in above graph we can see thar it is predicting near to tha actual value and RMSE error is very less

# %%
#importing library for classification prediction
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
#assign the value of x and y for training and testing phase
x_c = df.drop(columns=['region','Date'])
y_c = df[["region"]]
print(x_c.shape)
print(y_c.shape)
# Out:
# (17651, 12)
# (17651, 1)

# %%
#Standardize the value of x so that mean will 0 and SD will become 1 , and make the data as normal distributed
sc = StandardScaler()
sc.fit_transform(x_c)
x_c = pd.DataFrame(x_c,columns=x_c.columns)

# %%
# here we are taking region as output variable and trying prediction using classification method

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeClassifier(),KNeighborsClassifier()]
max_accuracy_score = 0
for r_state in range(40,90):
    train_xc,test_xc,train_yc,test_yc = train_test_split(x_c,y_c,random_state = r_state,test_size = 0.33)
    for i_c in model:
        i_c.fit(train_xc,train_yc)
        pre_c = i_c.predict(test_xc)
        ac_score = accuracy_score(test_yc,pre_c)
        print("accuracy score correspond to random state " ,r_state ,"is", ac_score)
        if ac_score> max_accuracy_score:
            max_accuracy_score=ac_score
            final_state = r_state
            final_model = i_c
            
print()
print()
print()
print()

print("max accuracy score correspond to random state " ,final_state , "is" , max_accuracy_score ,"and model is",final_model)
# Out:
# accuracy score correspond to random state  40 is 0.7787124463519314
# accuracy score correspond to random state  40 is 0.7787124463519314
# accuracy score correspond to random state  41 is 0.7785407725321889
# accuracy score correspond to random state  41 is 0.783519313304721
# accuracy score correspond to random state  42 is 0.7828326180257511
# accuracy score correspond to random state  42 is 0.7809442060085837
# accuracy score correspond to random state  43 is 0.7847210300429185
# accuracy score correspond to random state  43 is 0.7783690987124463
# accuracy score correspond to random state  44 is 0.7836909871244635
# accuracy score correspond to random state  44 is 0.7788841201716739
# accuracy score correspond to random state  45 is 0.7850643776824034
# accuracy score correspond to random state  45 is 0.7866094420600859
# accuracy score correspond to random state  46 is 0.7910729613733906
# accuracy score correspond to random state  46 is 0.7933047210300429
# accuracy score correspond to random state  47 is 0.7862660944206008
# accuracy score correspond to random state  47 is 0.7799141630901287
# accuracy score correspond to random state  48 is 0.7881545064377682
# accuracy score correspond to random state  48 is 0.7811158798283262
# accuracy score correspond to random state  49 is 0.775793991416309
# accuracy score correspond to random state  49 is 0.7831759656652361
# accuracy score correspond to random state  50 is 0.7869527896995708
# accuracy score correspond to random state  50 is 0.7884978540772533
# accuracy score correspond to random state  51 is 0.7811158798283262
# accuracy score correspond to random state  51 is 0.7783690987124463
# accuracy score correspond to random state  52 is 0.7862660944206008
# accuracy score correspond to random state  52 is 0.7879828326180257
# accuracy score correspond to random state  53 is 0.7881545064377682
# accuracy score correspond to random state  53 is 0.7833476394849785
# accuracy score correspond to random state  54 is 0.7855793991416309
# accuracy score correspond to random state  54 is 0.7840343347639485
# accuracy score correspond to random state  55 is 0.7792274678111588
# accuracy score correspond to random state  55 is 0.791244635193133
# accuracy score correspond to random state  56 is 0.7824892703862661
# accuracy score correspond to random state  56 is 0.7804291845493562
# accuracy score correspond to random state  57 is 0.7802575107296137
# accuracy score correspond to random state  57 is 0.7723605150214592
# accuracy score correspond to random state  58 is 0.7869527896995708
# accuracy score correspond to random state  58 is 0.7847210300429185
# accuracy score correspond to random state  59 is 0.7871244635193133
# accuracy score correspond to random state  59 is 0.7909012875536481
# accuracy score correspond to random state  60 is 0.7871244635193133
# accuracy score correspond to random state  60 is 0.7893562231759657
# accuracy score correspond to random state  61 is 0.7907296137339056
# accuracy score correspond to random state  61 is 0.7821459227467811
# accuracy score correspond to random state  62 is 0.7891845493562232
# accuracy score correspond to random state  62 is 0.7872961373390558
# accuracy score correspond to random state  63 is 0.775793991416309
# accuracy score correspond to random state  63 is 0.7811158798283262
# accuracy score correspond to random state  64 is 0.7787124463519314
# accuracy score correspond to random state  64 is 0.7914163090128755
# accuracy score correspond to random state  65 is 0.7869527896995708
# accuracy score correspond to random state  65 is 0.7826609442060086
# accuracy score correspond to random state  66 is 0.7881545064377682
# accuracy score correspond to random state  66 is 0.7934763948497854
# accuracy score correspond to random state  67 is 0.7742489270386266
# accuracy score correspond to random state  67 is 0.7872961373390558
# accuracy score correspond to random state  68 is 0.7814592274678112
# accuracy score correspond to random state  68 is 0.7874678111587983
# accuracy score correspond to random state  69 is 0.7871244635193133
# accuracy score correspond to random state  69 is 0.7828326180257511
# accuracy score correspond to random state  70 is 0.7866094420600859
# accuracy score correspond to random state  70 is 0.7843776824034335
# accuracy score correspond to random state  71 is 0.7895278969957081
# accuracy score correspond to random state  71 is 0.7878111587982832
# accuracy score correspond to random state  72 is 0.7840343347639485
# accuracy score correspond to random state  72 is 0.7876394849785407
# accuracy score correspond to random state  73 is 0.7866094420600859
# accuracy score correspond to random state  73 is 0.7867811158798284
# accuracy score correspond to random state  74 is 0.7855793991416309
# accuracy score correspond to random state  74 is 0.7896995708154506
# accuracy score correspond to random state  75 is 0.784549356223176
# accuracy score correspond to random state  75 is 0.7890128755364807
# accuracy score correspond to random state  76 is 0.7776824034334764
# accuracy score correspond to random state  76 is 0.7888412017167382
# accuracy score correspond to random state  77 is 0.7795708154506438
# accuracy score correspond to random state  77 is 0.7787124463519314
# accuracy score correspond to random state  78 is 0.7910729613733906
# accuracy score correspond to random state  78 is 0.7852360515021459
# accuracy score correspond to random state  79 is 0.7934763948497854
# accuracy score correspond to random state  79 is 0.7910729613733906
# accuracy score correspond to random state  80 is 0.784892703862661
# accuracy score correspond to random state  80 is 0.791931330472103
# accuracy score correspond to random state  81 is 0.7821459227467811
# accuracy score correspond to random state  81 is 0.7807725321888412
# accuracy score correspond to random state  82 is 0.7891845493562232
# accuracy score correspond to random state  82 is 0.7855793991416309
# accuracy score correspond to random state  83 is 0.7871244635193133
# accuracy score correspond to random state  83 is 0.7807725321888412
# accuracy score correspond to random state  84 is 0.7907296137339056
# accuracy score correspond to random state  84 is 0.7936480686695279
# accuracy score correspond to random state  85 is 0.7749356223175966
# accuracy score correspond to random state  85 is 0.7831759656652361
# accuracy score correspond to random state  86 is 0.7823175965665236
# accuracy score correspond to random state  86 is 0.7962231759656653
# accuracy score correspond to random state  87 is 0.7781974248927038
# accuracy score correspond to random state  87 is 0.7879828326180257
# accuracy score correspond to random state  88 is 0.7931330472103004
# accuracy score correspond to random state  88 is 0.7862660944206008
# accuracy score correspond to random state  89 is 0.783519313304721
# accuracy score correspond to random state  89 is 0.7871244635193133
#
#
#
#
# max accuracy score correspond to random state  86 is 0.7962231759656653 and model is KNeighborsClassifier()

# %%
# max accuracy score correspond to random state  86 is 0.7962231759656653 and model is KNeighborsClassifier

# %%
#Checking the best parameter for prediction of KNeighborsClassifier Algo using GridSearchCV
train_xc,test_xc,train_yc,test_yc = train_test_split(x_c,y_c,random_state = 86,test_size = 0.33)
KNC = KNeighborsClassifier()
parameters={'n_neighbors' : range(1,30)}
gridsearch=GridSearchCV(KNC,parameters)
gridsearch.fit(train_xc,train_yc)
gridsearch.best_params_
# Out:
# {'n_neighbors': 1}

# %%
KNC = KNeighborsClassifier(n_neighbors=1)
KNC.fit(train_xc,train_yc)
predc = KNC.predict(test_xc)
acu_score = accuracy_score(test_yc,predc)
print("Accuracy Score :",acu_score*100)
# Out:
# Accuracy Score : 83.84549356223175

# %%
#Calculating the scores of different parameters
score = cross_val_score(KNC,x_c,y_c,cv = 100,scoring='accuracy').mean()
print('Cross_val_score : ', score*100)
print('Mean Score      : ' , score.mean()*100)
print('STD score       : ' , score.std())
# Out:
# Cross_val_score :  80.05164997431949
# Mean Score      :  80.05164997431949
# STD score       :  0.0

# %%
pred_prob = KNC.predict_proba(test_xc)[:,1]
pred_prob
# Out:
# array([0., 0., 1., ..., 0., 0., 0.])

# %%
fpr,tpr,thresholds = roc_curve(test_yc,pred_prob,pos_label=True)

# %%
print(fpr)
print("\n")
print(tpr)
print("\n")
print(thresholds)
# Out:
# [0.         0.00454625 1.        ]
#
#
# [0.         0.75471698 1.        ]
#
#
# [2. 1. 0.]

# %%
#Plotting the graph which tells us about the area under curve , more the area under curve more will be the better prediction

plt.plot([0,1],[1,0],'k--')
plt.plot(fpr,tpr,label = 'KNeighborsClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('KNeighborsClassifier')
plt.show()

# %%
# conclusion:

# taking price as y variable is predicting well for this model as comapared to region
# also r2 score value is also greater then accuracy score

# %%
#save the model 
jb.dump(KNN, 'Avacado_Project.pk1')
# Out:
# ['Avacado_Project.pk1']
